# %%
import numpy as np
x=np.array([[25,2],[5,26],[3,7]])
y=np.array([[2,2],[5,24],[0,7]])
x*y
# Out:
# array([[ 50,   4],
#        [ 25, 624],
#        [  0,  49]])

# %%
import torch
X_pt=torch.tensor([[25,2],[5,26],[3,7]])
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
import tensorflow as tf
X_tf=tf.Variable([[25,2],[5,26],[3,7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])>

# %%
import tensorflow as tf
X_tf=tf.Variable([[25,2],[5,26],[3,7]])
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[25,  5,  3],
#        [ 2, 26,  7]])>

# %%
import numpy as np
a=np.array([[4,2],[-2,7]])
b=np.array([8,11])
x=np.linalg.solve (a,b)
x
# Out:
# array([1.0625, 1.875 ])

# %%
import torch
a=torch.tensor([[4,2],[-2,7]])
b=torch.tensor([8,11])
x=torch.linalg.solve(a,b)
x
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [23], line 4
#       2 a=torch.tensor([[4,2],[-2,7]])
#       3 b=torch.tensor([8,11])
# ----> 4 x=torch.linalg.solve(a,b)
#       5 x
#
# RuntimeError: linalg.solve: Expected a floating point or complex tensor as input. Got Long

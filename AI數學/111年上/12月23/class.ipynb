# %%
import numpy as np
import matplotlib.pyplot as plt 
from sympy.solvers import solve
from sympy import Symbol

def fun1 (x):
    return (x**2-4)/(x-2)
x=Symbol('x')

x1=1
x2=2
x3=3

y1=fun1(x1)
y2=fun1(x2)
y3=fun1(x3)



xr = np.linspace(-10, 10, 50)

plt.text(0, 55, 'y=7-8x-2x^2', fontsize=16, color='blue')
y1r = fun1(xr) 

plt.xlim(-10, 10)
plt.ylim(-100, 100)
plt.plot(xr,y1r,'r-')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11108/1215542669.py in <module>
#      13
#      14 y1=fun1(x1)
# ---> 15 y2=fun1(x2)
#      16 y3=fun1(x3)
#      17
#
# ~\AppData\Local\Temp/ipykernel_11108/1215542669.py in fun1(x)
#       5
#       6 def fun1 (x):
# ----> 7     return (x**2-4)/(x-2)
#       8 x=Symbol('x')
#       9
#
# ZeroDivisionError: division by zero

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sympy.solvers import solve
from sympy import Symbol

def fun1(x):
    return -8 + 12 *x + 6 * x ** 2 
x=Symbol('x') 
x1 = 1
x2 = 2
x3 = 3

y1= fun1 (x1)
y2 = fun1 (x2)
y3 = fun1 (x3)

plt.plot(x1, y1, 'go', markersize=10)
plt.plot(x2, y2, 'go', markersize=10)
plt.plot(x3, y3, 'go', markersize=10)

xr = np.linspace (0, 8, 50)

plt.text (2.5, 55, 'y=-8+12x+6x^2', fontsize=12, color='blue')

y1r = fun1 (xr)
plt.plot(xr, y1r, 'b-')
plt.text(1, 8, 'y=12-5x', fontsize=12, color='blue')
plt.xlim(0, 4)
plt.ylim(-20, 120)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sympy.solvers import solve
from sympy import Symbol


def fun1(x):
    return 2*(x + 1) ** 2 + 3
x=Symbol('x') 
xData = list (range (-6, 5))
yData =  list() 
for xVa1 in xData:
    yVa1= fun1 (xVa1)
    yData.append(yVa1)
    plt.plot (xVa1, yVa1, 'go', markersize=8) 
    plt.text (xVa1, yVa1+0.5, '('+str(xVa1)+', '+str (yVa1)+')', fontsize=12, color='red')


plt.text(-3, 25, 'y = 2 * (x + 1)^2 + 3', fontsize=16, color='blue')
xr = np.linspace (-6, 4, 50)
y1r = fun1 (xr)

plt.plot(xr, y1r, 'b-')
plt.xlim (-15, 15)
plt.ylim (-60, 60)
plt.grid(True)

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
from sympy.solvers import solve
from sympy import Symbol

#plt.rcParams['font.sans-serif']=['Heiti TC']
def fun1 (x): 
    return x** 2
def fun2(x):
    return 2*x ** 2
def fun3(x):
    return 3*x ** 2
x=Symbol('x') 

xData = list(range(-4, 5))
yData = list()

plt.text (4, 15, 'y=x^2', fontsize=14, color='blue')
plt.text (4, 35, 'y=2x^2', fontsize=14, color='green')
plt.text (4, 50, 'y=3x^2', fontsize=14, color='red')
xr = np.linspace (-4, 4, 50)

y1r = fun1 (xr)
y2r = fun2 (xr)
y3r = fun3 (xr)
plt.plot(xr, y1r, 'b-')
plt.plot(xr, y2r, 'g-') 
plt.plot(xr, y3r, 'r-')
plt.xlim (-15, 15)
plt.ylim (-60, 60)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy.solvers import solve
from sympy import Symbol

def fun1 (x):
    return 216 + 560 * x - 100 * x ** 2

x = Symbol('x')
x1 = 1
x2 = 2
x3 = 3

y1 = fun1 (x1)
y2 = fun1 (x2)
y3 = fun1 (x3)

plt.plot(x1, y1, 'go', markersize=10)
plt.plot(x2, y2, 'go', markersize=10)
plt.plot(x3, y3, 'go', markersize=10)

xr = np.linspace (0, 5, 50)
plt.text(1, 500, 'y =216+560x-100x^2', fontsize=12, color='blue')

y1r = fun1(xr)
plt.plot(xr, y1r, 'b-')

plt.xlim(0, 5)
plt.ylim(0,1200)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sympy.solvers import solve
from sympy import Symbol

def funl (x):
    return 216 + 560 *x-100*x**2


def fun2 (x):
    return 900 +x * 0

x = Symbol ('x')
x1 = 1
x2 = 2
x3 = 3
x4 = 1.8
x5 = 3.8
y1 = funl (x1)
y2 = fun1 (x2)
y3 = fun1 (x3)
y4 = fun1 (x4)
y5 = fun1 (x5)
plt.plot(x1, y1, 'go', markersize=10)
plt.plot(x2, y2, 'go', markersize=10)
plt.plot(x3, y3, 'go', markersize=10)
plt.plot(x4, y4, 'ro', markersize=10)
plt.plot(x5, y5, 'ro', markersize=10)   
xr = np.linspace(0, 5, 50)
ylr = fun1 (xr)
y2r = fun2 (xr)

plt.plot(xr, y1r, 'b-') 
plt.plot(xr, y2r, 'g-')

plt.text(1, 500, 'y =216+560x-100x^2', fontsize=12, color='blue') 
plt.text(1.8, 840, '(1.8, 900)', fontsize=12, color='blue') 
plt.text(3.9,910, '(3.8,900)', fontsize=12, color='blue')

plt.xlim(0, 5)
plt.ylim(0, 1200)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy.solvers import solve 
from sympy import Symbol

plt.rcParams['font.sans-serif'] == ['Heiti TC']

def fun1(x):
    return -25 +35 *x
x = Symbol ('x') 

x1 = 1
x2 = 2
x3 = 3
y1 = fun1 (x1)
y2 = fun1 (x2)
y3 = fun1 (x3)

plt.plot(x1, y1+1, 'go', markersize=8)
plt.plot(x2, y2-2, 'go', markersize=8)
plt.plot(x3, y3+2, 'go', markersize=8)

xr = np.linspace (0, 8, 50)
y1r = fun1 (xr)

plt.xlabel('拜訪次數 x (百次)', fontsize=12, color='blue')
plt.ylabel('簽約件數y', fontsize=12, color='blue')

plt.plot(xr, y1r, 'b-')

plt.xlim (0, 4)
plt.ylim (0, 120)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy.solvers import solve 
from sympy import Symbol

#plt.rcParams['font.sans-serif'] = ['Heiti TC']
def fun1 (x): 
    return -28 +36 * x

x = Symbol('x')
x1 = 1
x2 = 2
x3 = 3

y1 = 10
y2 = 40
y3 = 82

plt.plot (x1, y1, 'go', markersize=8)
plt.plot (x2, y2, 'go', markersize=8)
plt.plot (x3, y3, 'go', markersize=8)

xr = np.linspace (0, 8, 50)

y1r=fun1 (xr)
plt.text(2, 100, 'y -28 +36x', fontsize=16, color='blue')
plt.text(1.3, 10, '(1, 10)', fontsize=14, color='red')
plt.text(2.3, 40, '(2, 40)', fontsize=14, color='red')
plt.text(3.3, 82, '(3, 82)', fontsize=14, color='red')

plt.xlabel('拜訪次數 x (百次)', fontsize=12, color='blue')
plt.ylabel('簽約件數y', fontsize=12, color='blue')

plt.plot(xr, y1r, 'b-')

plt.xlim (0,5)
plt.ylim (0, 150)
plt.grid (True)

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Heiti TC
# ...

# %%
x=list(map(int,input().split()))
for i in range(len(x)):
    for j in range(i+1,len(x)):
        if x[i]>x[j]:
            a=x[i]
            x[i]=x[j]
            x[j]=a
for i in x:
    print(i,'\t',end='')
# Out:
# 0 	3 	6 	7 	8 	9 	45

# %%
while True:
    x=list(map(int,input().split()))
    if x.find(-1)>=0:
        break
    for i in range()

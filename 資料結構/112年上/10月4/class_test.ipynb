# %%
import matplotlib.pyplot as plt
import numpy as np

def O_1(n):
    return n*(1/n)

def O_n(n):
    return n

def O_n2(n):
    return n**2

def O_n3(n):
    return n**3

def O_2n(n):
    return 2**n

def O_log2n(n):
    return np.log2(n)

def O_nlog2n(n):
    return np.log2(n)*n

x = np.linspace(0.1, 10, 1000)
plt.figure(figsize=(12, 8))

plt.plot(x, O_1(x), label="O(1)")
plt.plot(x, O_n(x), label="O(n)")
plt.plot(x, O_n2(x), label="O(n^2)")
plt.plot(x, O_n3(x), label="O(n^3)")
plt.plot(x, O_2n(x), label="O(2^n)")
plt.plot(x, O_log2n(x), label="O(n*log2(n))")
plt.plot(x, O_nlog2n(x), label="O(log2(n))")

plt.title("Big O")
plt.xlabel("x")
plt.ylabel("y")

plt.ylim(-1, 10)
plt.legend()
plt.show()

# %%
class Array:
    def __init__(self):
        self.elements = []
    
    def traverse(self):
            for element in self.elements:
                print(element)

    def insertion(self, index, value):
        self.elements = self.elements[:index] + [value] + self.elements[index:] 
    
    def deletion(self, index):
            self.elements = self.elements[:index] + self.elements[index+1:]

    def search(self, index=None, value=None):
        if index is not None:
            return self.elements[index]
        elif value is not None:
            return self.elements.index(value)
        else:
            return None

    def update(self, index, value):
        self.elements[index] = value

test = Array()

test.elements = [1, 2, 3, 4, 5]
# Out:
# Traverse:
# [0]: 1
# [1]: 2
# [2]: 3
# [3]: 4
# [4]: 5
# Insertion:
# [1, 2, 2, 3, 4, 5]
# Deletion:
# [1, 2, 3, 4, 5]
# Update:
# [1, 2, 3, 8, 5]
# Search:
# index: 3
# index: 8
